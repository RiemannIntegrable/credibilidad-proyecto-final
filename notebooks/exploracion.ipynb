# %% [markdown]
# <div align = "center">
#
# # **Exploración de datos**
#
# </div>

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data
