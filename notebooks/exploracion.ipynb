# %% [markdown]
# <div align = "center">
#
# # **Exploracion**
#
# </div>

# %% [markdown]
# ## Librerias

# %%
import pandas as pd

# %% [markdown]
# ## Data

# %%
expuestos = pd.read_csv("../data/in/ProdCumpli.csv", sep=';')
siniestros = pd.read_csv("../data/in/SiniesCumpli.csv", sep=';')

# %% [markdown]
# ## Exploracion

# %% [markdown]
# columnas

# %%
expuestos.columns
# Out:
# Index(['conta,"anio","Mes","Poliza","CodSucursal","Ramo","VigenciaInicioPoliza","VigenciaFinPoliza","ValorPrimaEquiv","Amparo"'], dtype='object')

# %%
siniestros.columns
# Out:
# Index(['Conta', 'anio', 'Mes', 'cod_suc', 'SINIESTRO', 'POLIZA',
#        'DEPARTAMENTO_SINIESTRO', 'VALOR_ASEGURADO', 'FECHA_DE_SINIESTRO',
#        'FECHA_AVISO', 'AMPARO', 'ULT_FECHA_PAGO', 'PAGOS',
#        'RESERVA_ACTUAL_EQUI', 'RAMO'],
#       dtype='object')
